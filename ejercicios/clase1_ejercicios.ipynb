# %% [markdown]
# <a href="https://colab.research.google.com/github/estebanvillalba2007-source/curso_programacion_cientifica/blob/main/ejercicios/clase1_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicios

# %%
nombre = "wilson"
print(f"Hola, {nombre}. Bienvenida al curso.")
# Out:
# Hola, wilson. Bienvenida al curso.

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
nombre_producto = "cuaderno argollado"
precio= 2500
esta_disponible = True

# %%
type(nombre_producto)
# Out:
# str

# %% [markdown]
# "/" division con desimales
# "//" division sin desimales
# "%" residuo de la division
# "#" comentario

# %%
# cualcular el IVA del precio de producto y almacenarlo en una variable
iva = precio * 0.19
print(iva)
iva = precio * 0.19
print("precio del producto: " + str(precio))
print(f"valor del iva: {iva}")
print(f"El valor total es: {precio + iva}")
# Out:
# 475.0
# precio del producto: 2500
# valor del iva: 475.0
# El valor total es: 2975.0

# %%
precio = 15990.0
disponible = True
temperatura = 18.5

print(precio > 20000)          # ¿el precio supera los 20000?
print(precio == 15990.0)       # ¿el precio es exactamente 15990.0?
print(temperatura != 20)       # ¿la temperatura es distinta de 20?
# Out:
# False
# True
# True
